# %% [markdown]
# # **Project Name**    - AirBnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Airbnb has revolutionized the way people travel and experience the world since its inception in 2008. With millions of listings worldwide, Airbnb generates vast amounts of data that can be harnessed to gain insights into customer behavior, host performance, and make informed business decisions. This project aims to explore and analyze a dataset consisting of approximately 49,000 observations and 16 columns, containing a mix of categorical and numeric values, to uncover key understandings about Airbnb bookings.The dataset contains essential information about each listing, including unique IDs, names, host IDs, host names, location details such as neighborhood, area, latitude, and longitude range, etc.The primary objective of this EDA is to extract meaningful insights from the dataset, which can help Airbnb make informed decisions, improve customer experiences, and guide marketing initiatives. By performing exploratory data analysis (EDA), we aim to understand pricing patterns, popular neighborhoods, host behavior, and availability trends.
#  😃
#
# The analysis begins with a comprehensive EDA, where we examine the dataset's structure, check for missing values, and handle data inconsistencies. We explore the distribution of prices to identify the range of listing prices and potential outliers. By visualizing the data, we gain insights into pricing trends across different types of listings and geographical locations.
#
# Next, we investigate the relationship between minimum nights and pricing to understand the booking requirements and their impact on prices. We analyze the number of reviews and reviews per month to assess customer engagement and satisfaction levels. By examining the content of the last review, we can identify common themes or concerns shared by guests.
#
# To gain a deeper understanding of host performance, we analyze the calculated host listing count, which provides insights into the number of listings managed by each host. We explore host behavior in terms of availability, determining the number of days a listing is available throughout the year.
#
# Results and Insights:
# Through the analysis, several key understandings emerge. We uncover the distribution of prices, ranging from affordable options to luxury accommodations. By examining neighborhood and area information, we identify popular locations for Airbnb bookings. This information can be valuable for marketing strategies, targeting specific neighborhoods or areas.
#
# The analysis of minimum nights reveals the booking requirements set by hosts, influencing the pricing structure and guest preferences. Understanding the number of reviews and reviews per month provides insights into customer satisfaction levels and can guide improvements in service quality.
#
# Furthermore, analyzing the calculated host listing count helps identify superhosts or hosts managing multiple listings, indicating experienced and reliable hosts. This information can be utilized to promote host excellence and enhance trust among guests.
#
# Lastly, by analyzing availability throughout the year, we gain insights into seasonal patterns and identify periods of high or low demand. This knowledge can inform pricing strategies and help optimize revenue generation.
#
# Conclusion:
# Through the exploration and analysis of the Airbnb bookings dataset, we uncover valuable insights that can inform business decisions, enhance customer experiences, and guide marketing initiatives. The analysis sheds light on pricing patterns, popular neighborhoods, host performance, and availability trends. By leveraging these insights, Airbnb can refine its strategies, improve customer satisfaction, and maximize its competitive edge in the dynamic vacation rental market.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# GitHub Link : https://github.com/Sameernadaf216

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem statement revolves around extracting key insights from the Airbnb bookings dataset to address pricing optimization, customer satisfaction, host performance, and availability management. By tackling these challenges, Airbnb aims to enhance its business operations, deliver exceptional guest experiences, and maintain a competitive edge in the vacation rental market.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this Airbnb bookings analysis project is to leverage the dataset's insights and findings to drive informed decision-making, improve customer experiences, and optimize marketing strategies, host performance, and availability management.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Mount the drive to google colab by running below code
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
path='/content/drive/MyDrive/Airbnb NYC 2019.csv'

# Read the dateset by using .read_csv() method
data=pd.read_csv(path)

# Creating the Pandas dataframe by using .DataFrame() method then assing it to variable df
df=pd.DataFrame(data)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
missing_data = df.isnull().sum().reset_index()
missing_data.columns = ['Variable', 'Missing Count']

plt.figure(figsize=(10, 6))
sns.barplot(x='Missing Count', y='Variable', data=missing_data, palette='viridis')
plt.title('Missing Values Count')
plt.xlabel('Missing Count')
plt.ylabel('Variable')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset used for this Airbnb bookings analysis contains 48895 observations and consists of 16 columns. It is a mix of categorical and numeric values, providing valuable information about each listing.
#
# The dataset provides valuable insights into the characteristics of Airbnb listings, including location, pricing, review data, host information, and availability. By exploring and analyzing this dataset, we can uncover trends, patterns, and relationships that can be leveraged to make informed business decisions, enhance customer experiences, and optimize marketing strategies within the Airbnb platform.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# id: Unique ID assigned to each listing.
#
#
# ---
#
#
# name: Name of the listing.
#
#
# ---
#
#
# host_id: Unique ID assigned to each host.
#
#
# ---
#
#
# host_name: Name of the host.
#
#
# ---
#
#
#
# neighbourhood_group: Group or region where the
# listing is located.
#
#
# ---
#
#
# neighborhood: Neighborhood where the listing is situated.
#
# ---
#
#
#
# latitude: Latitude range of the listing's location.
#
#
# ---
#
#
# longitude: Longitude range of the listing's location.
#
#
# ---
#
#
# room_type: Type of listing, categorized as "Entire home," "Private room," or "Shared room."
#
#
# ---
#
#
# price: Price of the listing per night.
#
#
# ---
#
#
# minimum_nights: Minimum number of nights required for booking the listing.
#
#
# ---
#
#
# number_of_reviews: Total number of reviews received for the listing.
#
#
# ---
#
#
# last_review: Content of the last review received for the listing.
#
#
# ---
#
#
# reviews_per_month: Average count of reviews per month for the listing.
#
#
# ---
#
#
# calculated_host_listing_count: Number of listings managed by the host.
#
#
# ---
#
#
# availability_365: Availability of the listing throughout the year, measured in the number of days.
#
#
# ---
#
#
# Note: Listing is nothing but the property of host

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("Number of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# Number of unique values in  id is 48895 .
# Number of unique values in  name is 47905 .
# Number of unique values in  host_id is 37457 .
# Number of unique values in  host_name is 11452 .
# Number of unique values in  neighbourhood_group is 5 .
# Number of unique values in  neighbourhood is 221 .
# Number of unique values in  latitude is 19048 .
# Number of unique values in  longitude is 14718 .
# Number of unique values in  room_type is 3 .
# Number of unique values in  price is 674 .
# Number of unique values in  minimum_nights is 109 .
# Number of unique values in  number_of_reviews is 394 .
# Number of unique values in  last_review is 1764 .
# Number of unique values in  reviews_per_month is 937 .
# Number of unique values in  calculated_host_listings_count is 47 .
# Number of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Let we get some statistical measures for some columns
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# As there is minimum value of price is zero dollar, which doesn't makes any sense
# Keep rows where price is greater than zero
df = df[df['price'] > 0]

# %%
#Dropping duplicate values
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10051
# reviews_per_month                 10051
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#Dropping unnecessary columns
df.drop(['name','id','last_review'], axis=1, inplace=True)

# %%
#Examining Changes
df.isnull().sum()
# Out:
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10051
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#Replace the null values in 'reviews per month' by zero
df.fillna({'reviews_per_month':0}, inplace=True)
#examing changes
df.reviews_per_month.isnull().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.888400e+04  48884.000000  48884.000000  48884.000000    48884.000000
# mean   6.762203e+07     40.728953    -73.952176    152.755053        7.029887
# std    7.861666e+07      0.054532      0.046159    240.170260       20.512224
# min    2.438000e+03     40.499790    -74.244420     10.000000        1.000000
# 25%    7.817310e+06     40.690100    -73.983080     69.000000        1.000000
# 50%    3.079257e+07     40.723080    -73.955685    106.000000        3.000000
# 75%    1.074344e+08     40.763120    -73.936290    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48884.000000       48884.000000                    48884.000000
# mean           23.271991           1.090800                        7.144628
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48884 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48884 non-null  int64
#  1   host_name                       48863 non-null  object
#  2   neighbourhood_group             48884 non-null  object
#  3   neighbourhood                   48884 non-null  object
#  4   latitude                        48884 non-null  float64
#  5   longitude                       48884 non-null  float64
#  6   room_type                       48884 non-null  object
#  7   price                           48884 non-null  int64
#  8   minimum_nights                  48884 non-null  int64
#  9   number_of_reviews               48884 non-null  int64
#  10  reviews_per_month               48884 non-null  float64
#  11  calculated_host_listings_count  48884 non-null  int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Droping that rows which has price equal to zero
# 2. Droping the duplicates values to get more accuracy in output.
#
# 3. Dropping unnecessary columns like 'name','id','last_review', because these columns are not used in analysis.
# 4. As 'reviews_per_month'column contains 10052 null values can be filled with 0

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Barplot

# %%
sns.barplot(x=df['neighbourhood_group'],y=df['calculated_host_listings_count'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the relation between the neighbourhood_group vs. calculated_host_listings_count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The Manhattan area has the high number of calculated_host_listings_count.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As calculated_host_listings_count in the Manhattan are more which tells that there are less number of hosts but more number of listing, Therefore giving the discount to those hosts can increase the bond between the AirBnb and Hosts.

# %% [markdown]
# #### Chart - 2 Scatterplot to get location of listings

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8,6))
sns.scatterplot(x=df.longitude,y=df.latitude,hue=df.neighbourhood_group)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the location of listings of different neighbourhood_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatterplot above we observe that Staten Island cluster is away from the other neighborhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Staten Island is distinct from other neighborhood groups, can inform marketing and targeting strategies. Airbnb can develop specific marketing campaigns or tailored experiences highlighting the unique features and attractions of Staten Island to attract more guests to that area. By catering to the preferences and needs of travelers interested in Staten Island, Airbnb can increase bookings in that region and drive positive business impact.

# %% [markdown]
# #### Chart - 3 Pie chart to analyse Neighbourhood Group

# %%
# Chart - 3 visualization code
nhg_pct = df['neighbourhood_group'].value_counts()
px.pie(nhg_pct, values=nhg_pct.values, names=nhg_pct.index, title='Neighbourhood Group', width=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the distribution of listings in different Neighbourhood Group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Pie chart concludes that Majority of the Rooms or Apartments are in the Manhattan and Brooklyn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While Manhattan and Brooklyn are already popular, the insight from the pie chart may also guide Airbnb's expansion strategies. It can help identify potential growth opportunities in other neighborhoods or regions that have a relatively smaller share of listings. By strategically expanding into these areas, Airbnb can tap into new markets, attract a diverse range of hosts and guests, and diversify their offerings.

# %% [markdown]
# #### Chart - 4 Histogram plot for different room_type and neighourhood_groups

# %%
# Chart - 4 visualization code
# Mean prices by room type for different neighbourhood groups
df.groupby(['neighbourhood_group', 'room_type'])['price'].mean()
# Out:
# neighbourhood_group  room_type
# Bronx                Entire home/apt    127.506596
#                      Private room        66.890937
#                      Shared room         59.800000
# Brooklyn             Entire home/apt    178.346202
#                      Private room        76.545428
#                      Shared room         50.773723
# Manhattan            Entire home/apt    249.257994
#                      Private room       116.776622
#                      Shared room         88.977083
# Queens               Entire home/apt    147.050573
#                      Private room        71.762456
#                      Shared room         69.020202
# Staten Island        Entire home/apt    173.846591
#                      Private room        62.292553
#                      Shared room         57.444444
# Name: price, dtype: float64

# %%
# facetgrid plotly
fig = px.histogram(df, x='neighbourhood_group', y='price', color='room_type', facet_col='room_type', facet_col_wrap=3,
                category_orders={'neighbourhood_group': df.neighbourhood_group.value_counts().index}, histfunc='avg')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the average price for different room type and also for different neighbourhoo_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Prices for all room types are generally high in Manhattan compared to other neighborhood groups.
# 2. Staten Island tends to have lower prices across all room types compared to other neighborhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Understanding the price variations by room type and neighborhood group can help Airbnb optimize their pricing strategies. They can set competitive prices based on the market demand and the characteristics of different areas. It allows them to attract guests with varying budgets and preferences while maximizing revenue potential.
# 2. Knowing that Manhattan has higher prices and attracts guests looking for premium accommodations, Airbnb can tailor their marketing efforts and promotional campaigns to highlight the unique features and experiences offered in Manhattan. They can also target specific customer segments who are willing to pay higher prices for luxury or exclusive stays.

# %% [markdown]
# #### Chart - 5 Boxplot for Neighbourhood Group vs. Availability Room

# %%
# Chart - 5 visualization code
plt.style.use('classic')
plt.figure(figsize=(8,6))
plt.title("Neighbourhood Group vs. Availability Room")
sns.boxplot(data=df, x='neighbourhood_group',y='availability_365',palette="dark")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the relationship between the availability room and neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph above shows the relationship between the availability room and neighborhood group where we can see that in Bronx the availability of rooms are for longer period of time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1.  They can identify areas with high demand and low availability, encouraging hosts in those areas to increase the availability of their listings to meet customer needs. This can help improve customer satisfaction and drive positive business impact.
# 2. If certain neighborhood groups have consistently low availability, Airbnb may consider targeting those areas for expansion by recruiting new hosts or encouraging existing hosts to offer listings in those locations. This can help increase inventory and meet the demand of potential guests, leading to business growth.

# %% [markdown]
# #### Chart - 6 Boxplot to visualize the neighbourhood_group vs. price

# %%
# Chart - 6 visualization code
px.box(df, x='neighbourhood_group', y='price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the relationship between the neighbourhood_group and price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Price for the Manhattan and Brooklyn are high.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  1. Airbnb can highlight the unique features and experiences offered in Manhattan and Brooklyn to attract guests seeking luxury or premium accommodations. They can also target guests looking for more affordable options by emphasizing the value and affordability of listings in other neighborhood groups.
#
# 2. The insights can be shared with hosts, allowing them to better understand pricing dynamics in their respective neighborhood groups. Hosts can adjust their pricing strategies accordingly and optimize their revenue potential. This can lead to higher host satisfaction and engagement with the platform.

# %% [markdown]
# #### Chart - 7  Boxplot to visualization room_type and prices

# %%
# Chart - 7 visualization code
px.box(df, x='room_type', y='price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the relationship between the room_type and price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. In room type the Entire home/apt type is having high price while compare to other room type.
# 2. It provides information about the median price (line inside the box), the interquartile range (box), and any outliers (points outside the whiskers).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Airbnb can highlight the value and benefits of entire homes/apartments to attract guests seeking a premium and exclusive experience. They can also emphasize the affordability and flexibility of other room types to cater to a wider range of travelers.
# 2. Sharing the insights with hosts can help them understand the pricing dynamics of different room types. Hosts can optimize their pricing strategies based on the insights, ensuring competitive prices for their listings. This can lead to higher host satisfaction, increased engagement, and a positive impact on the overall business.

# %% [markdown]
# #### Chart - 8 Barplot to visualize  average daily price vs. neighbourhood group

# %%
# Chart - 8 visualization code
df1 = df[df['minimum_nights']==1]
df1 = df1.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True)
print('List of Average Price per night based on the neighbourhood group')
pd.DataFrame(df1).sort_values(by='room_type')
# Out:
# List of Average Price per night based on the neighbourhood group
#                                           price
# room_type       neighbourhood_group
# Entire home/apt Queens               139.036260
#                 Bronx                141.541176
#                 Brooklyn             202.895245
#                 Staten Island        266.205128
#                 Manhattan            291.784595
# Private room    Bronx                 69.025862
#                 Staten Island         71.394366
#                 Queens                72.454958
#                 Brooklyn              81.791454
#                 Manhattan            121.434183
# Shared room     Staten Island         21.000000
#                 Bronx                 46.711111
#                 Brooklyn              60.921212
#                 Queens                68.459459
#                 Manhattan             88.462898

# %%
plt.figure(figsize=(12,8))
df1.plot(kind='bar')
plt.title('Average Price for rooms/night in neighbourhood group')
plt.ylabel('Average Daily Price')
plt.xlabel('Neighbourhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the average price per night for different room type in neighbourhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. In Manhattan the average price per night for Entire home/apt is high.
# 2. And for the shared room the average price is less.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. The insights gained from analyzing average prices per night can also inform Airbnb's expansion strategies. They can identify areas where the average prices are relatively low but have potential for growth. By targeting these areas for expansion, Airbnb can tap into new markets and diversify their revenue streams.
# 2.  The insights on average prices per night can be valuable for forming strategic partnerships with local businesses and tourism organizations. Airbnb can collaborate with hotels, travel agencies, and tour operators in high-demand areas to offer combined packages or discounts. This can enhance the overall travel experience for customers and create mutually beneficial partnerships.

# %% [markdown]
# #### Chart - 9 Top 5 host

# %%
# Chart - 9 visualization code
plt.figure(figsize=(12,6))
df['host_name'].value_counts()[:5].plot(kind='bar',color=['r','b','g','y','m'])
plt.title('Top 5 host')
plt.ylabel('Number of listings')
plt.xlabel('Host names')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Barplot is best for visualizing the top 5 host.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Michael and David are the top 2 host who has higher number of listings in AirBnb platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# AirBnb can give some discount to top hosts, So that AirBnb can develop the strong bond with hosts.

# %% [markdown]
# #### Chart - 10 Top 10 Apartment listings

# %%
# Chart - 10 visualization code
apt = df[df['room_type']=='Entire home/apt']
list_apt = apt.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='apartment').sort_values(by=['apartment'],ascending=False)
list_apt.head(10)
# Out:
#          host_id     host_name       neighbourhood neighbourhood_group  \
# 20209  219517861  Sonder (NYC)  Financial District           Manhattan
# 6449     7503643          Vida          Greenpoint            Brooklyn
# 8429    12243051        Sonder  Financial District           Manhattan
# 20212  219517861  Sonder (NYC)         Murray Hill           Manhattan
# 17830  120762452       Stanley         Murray Hill           Manhattan
# 19898  205031545    Red Awning             Midtown           Manhattan
# 12271   30283594          Kara      Hell's Kitchen           Manhattan
# 17449  107434423    Blueground             Chelsea           Manhattan
# 17626  113805886        Yaacov     Upper East Side           Manhattan
# 12273   30283594          Kara             Midtown           Manhattan
#
#        apartment
# 20209        210
# 6449          52
# 8429          51
# 20212         50
# 17830         49
# 19898         49
# 12271         41
# 17449         37
# 17626         33
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualise the neighbourhood vs. number of apartment

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Financial District has the highest number of apartment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As there are more number of apartment in the Financail District indirectly the number of guests are also more, therefore if AirBnb gives some discount to the hosts and guests that may attaract the hosts and customers.

# %% [markdown]
# #### Chart - 11 Top 10 private room

# %%
# Chart - 11 visualization code
private = df[df['room_type']=='Private room']
list_private = private.groupby(['host_id','host_name','neighbourhood']).size().reset_index(name='private').sort_values(by=['private'],ascending=False)
list_private.head(10)
# Out:
#          host_id host_name       neighbourhood  private
# 15261  190921808      John      Hell's Kitchen       44
# 14025  137358866    Kazuya            Woodside       35
# 16301  238321374      Eyal     Upper West Side       32
# 15984  224414117   Gabriel      Hell's Kitchen       30
# 16035  226410657      Nina  Bedford-Stuyvesant       26
# 16144  230192510      Zach         Fort Greene       25
# 16386  242962235     Yuval           Ridgewood       23
# 16539  252604696      Erin             Chelsea       20
# 15761  216235179      Nina            Bushwick       17
# 14024  137358866    Kazuya           Sunnyside       17

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualise the neighbourhood vs. number of private room.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Hell's kitchen has the highest number of private room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As there are more number of private room in the Hell's kitchen indirectly the number of guests are also more in that area, therefore if AirBnb gives some discount to the hosts and guests that may attaract the hosts and customers.

# %% [markdown]
# *italicized text*#### Chart - 12

# %%
# Chart - 12 visualization code
fig = plt.figure(figsize=(12,4))
review_50 = df[df['number_of_reviews']>=50]
df2 = review_50['neighbourhood_group'].value_counts()
df2.plot(kind='bar',color=['r','b','g','y','m'])
plt.title('Location and Review Score(Min of 50)')
plt.ylabel('Number of Review')
plt.xlabel('Neighbourhood Group')
plt.show()
print(' Count of Review v/s neighbourhood group')
pd.DataFrame(df2)
# Out:
#  Count of Review v/s neighbourhood group
#                neighbourhood_group
# Brooklyn                      3062
# Manhattan                     2751
# Queens                         997
# Bronx                          186
# Staten Island                   81

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the relationship between reviews and neighourhood_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We observe that there a lot of reviews for Manhattan and Brooklyn as compared to other neighbourhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Review is the one of the important criteria with online activity these days. This gives a lot of insights to a particular place for tourist and they can swing mood when it comes to online booking. A cheap place with bad review can drive a tourist for not booking and an expensive place with nicest review can shell a tourist more than what he have thought initially.

# %% [markdown]
# #### Chart - 12 Location and Review Score

# %%
# Chart - 13 visualization code
fig = plt.figure(figsize=(12,4))
review_50 = df[df['number_of_reviews']>=50]
df2 = review_50['neighbourhood_group'].value_counts()
df2.plot(kind='bar',color=['r','b','g','y','m'])
plt.title('Location and Review Score(Min of 50)')
plt.ylabel('Number of Review')
plt.xlabel('Neighbourhood Group')
plt.show()
print(' Count of Review v/s neighbourhood group')
pd.DataFrame(df2)
# Out:
#  Count of Review v/s neighbourhood group
#                neighbourhood_group
# Brooklyn                      3062
# Manhattan                     2751
# Queens                         997
# Bronx                          186
# Staten Island                   81

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the relationship between count of review and group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We observe that there a lot of reviews for Manhattan and Brooklyn as compared to other neighbourhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Review is the one of the important criteria with online activity these days. This gives a lot of insights to a particular place for tourist and they can swing mood when it comes to online booking. A cheap place with bad review can drive a tourist for not booking and an expensive place with nicest review can shell a tourist more than what he have thought initially.

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Chart - 1 visualization code
#Get Correlation between different variables
corr = df.corr(method='kendall')
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  The heatmap is used for visualizing correlation matrices in exploratory data analysis. It enables users to gain insights into the relationships between variables, identify patterns, and make informed decisions based on the correlation strengths and directions observed in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Number of listings managed by the host is positivily correlated to avaibility of listing by host for the year.
# 2. If the avaibility of listing is more throughout the year then number of reviews are also more.
# 3. As the Price of listing increases the number of host decreases.

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the pair plot with increased length of x-axis
sns.set(style="ticks")
subset_cols = ['price', 'minimum_nights', 'number_of_reviews', 'availability_365']
subset_df = df[subset_cols]
pair_plot = sns.pairplot(subset_df)

# Set the limits of the x-axis
pair_plot.set(xlim=(0, 1000))  # Adjust the values based on your data

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot is used to visualize the relationships between multiple variables in a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. There are some outliers in price vs. min_night & availability_365 vs. min_night which can be removed.
# 2. As the number of minimum night decreases the price value increases.
# 3. As the number of minimum night increases the availability_365.
# 4. The price and the availability_365 are almost constant.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. As staten Island is distinct from other neighborhood groups, AirBnb can use different marketing and targeting strategies for staten Island.
# 2. Manhattan is popular area and most of the revenue is generated from there therefore the AirBnb can make the strong bond with the hosts on the manhattan giving them a discount.
# 3. In room_type the entire home has high price and other room_type has less price therefore AirBnb can use different plans to attract the customers to other room_type.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Prices in Brooklyn and Manhattan are high for the Room types Private and Entire Homes.
#
# In the Bronx, the availability of rooms is for longer periods of time. We observe that there are a lot of reviews for Manhattan and Brooklyn as compared to other neighborhood groups.
#
# The top 5 hosts are David Michael Alex Jessica and Maria and we can give them rewards and loyalty points to them.
#
# What is interesting is that for Staten Island we see that there's very less engagement in terms of the number of reviews and Prices and can improvise by offering affordable prices and Refurnishing the property.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
